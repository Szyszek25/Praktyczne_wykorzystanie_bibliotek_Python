# %% [markdown]
# ---
# title: "Zadania - Wprowadzenie do fakultetu i narzędzi"
# format:
#   html:
#     code-tools: true
#     code-copy: true
#     code-line-numbers: true
#     highlight-style: github
# ---

# %%
#| echo: false
#| output: false
pass

# %% [markdown]
# # Ćwiczenie 1: Pierwszy notatnik Jupyter
#
# 1. Uruchom Jupyter notebook za pomocą komendy `jupyter notebook` w terminalu.
# 2. Stwórz nowy notatnik Python 3.
# 3. Zmień nazwę notatnika na `moj_pierwszy_notatnik.ipynb`.
# 4. W pierwszej komórce wpisz komentarz z dzisiejszą datą i swoim imieniem.
# 5. W kolejnej komórce napisz kod, który wyświetli "Witaj na zajęciach z Pythona!"
# 6. Zapisz notatnik.
#
# --------
#
# # Ćwiczenie 2: Eksploracja interfejsu Jupyter
#
# 1. Zapoznaj się z interfejsem Jupyter Notebook i znajdź następujące elementy:
#    - Przycisk do uruchamiania komórek
#    - Listę dostępnych kernelów
#    - Opcję zmiany typu komórki (Code/Markdown/Raw)
#    - Przycisk do dodawania nowych komórek
#    - Opcje zapisywania i zmiany nazwy notatnika
#
# 2. Eksperymentuj z trybami edycji i poleceń (Esc/Enter)
#    - Przełącz się między trybem edycji a trybem poleceń
#    - Użyj skrótów klawiszowych do:
#      - Wstawiania nowych komórek (A, B)
#      - Usuwania komórek (D, D)
#      - Zmiany typu komórki (M, Y)
#      - Podziału komórki (Ctrl + Shift + -)
#      - Scalania komórek (Shift + M)
#
# 3. Użyj funkcji autouzupełniania kodu (Tab) dla:
#    - Nazw zmiennych
#    - Metod obiektów
#    - Ścieżek do plików
#
# 4. Sprawdź dokumentację funkcji używając `?` i `??`
#
# --------
#
# # Ćwiczenie 3: Struktura pliku Jupyter Notebook
#
# 1. Otwórz swój notatnik `moj_pierwszy_notatnik.ipynb` w edytorze tekstowym (np. Notatnik, VS Code, Sublime Text).
# 2. Zauważ, że plik jest w formacie JSON, który jest formatem tekstowym do przechowywania strukturalnych danych.
# 3. Znajdź i zidentyfikuj w pliku:
#    - Komórki kodu (cells)
#    - Komórki Markdown
#    - Wyjście (output) z wykonanego kodu
#    - Metadane notatnika
# 4. Zapisz plik i spróbuj otworzyć go ponownie w Jupyter Notebook. Czy zauważasz jakieś zmiany w działaniu?
# 5. (Opcjonalne) Spróbuj ręcznie dodać nową komórkę Markdown do pliku JSON i sprawdź, czy poprawnie się wyświetla w notatniku.
#
# --------
#
# # Ćwiczenie 4: Eksploracja dostępnych funkcji
#
# 1. Użyj `%lsmagic` aby zobaczyć wszystkie dostępne magiczne komendy.
# 2. Sprawdź dokumentację wybranej magicznej komendy używając `?`.
# 3. Użyj `%quickref` aby zobaczyć szybką ściągawkę z funkcjami IPythona.
# 4. Użyj `%who` aby zobaczyć zdefiniowane zmienne.
#
# --------
#
# # Ćwiczenie 5: Podstawy IPython - dokumentacja i podpowiedzi
#
# 1. Używając znaku `?`, sprawdź dokumentację funkcji `print` i `len`.
# 2. Napisz własną funkcję i sprawdź jej kod źródłowy używając `??`.
# 3. Użyj autouzupełniania (klawisz Tab) aby zobaczyć dostępne metody dla listy `[1, 2, 3]`.
# 4. Użyj `%pinfo` aby zobaczyć szczegółowe informacje o obiekcie.
#
# --------
#
# # Ćwiczenie 6: Magiczne komendy IPython - pomiar czasu
#
# 1. Użyj `%timeit` aby zmierzyć czas wykonania operacji `[x**2 for x in range(1000)]`.
# 2. Użyj `%%time` aby zmierzyć czas wykonania całej komórki z pętlą:
#
#    ```python
#    result = []
#    for i in range(1000):
#        result.append(i**2)
#    ```
# 3. Porównaj wydajność obu podejść.
#
# --------
#
# # Ćwiczenie 7: Praca z systemem plików w IPython
#
# 1. Użyj magicznych comend aby wyświetlić zawartość bieżącego katalogu.
# 2. Stwórz nowy katalog o nazwie `dane` używając komendy systemowej.
# 3. Sprawdź swoją lokalizację w systemie plików używając `%pwd`.
# 4. Przejdź do katalogu domowego używając `%cd ~`.
# 5. Stwórz nowy plik `test.txt` i zapisz w nim kilka linijek tekstu używając komend systemowych.
# 6. Wyświetl zawartość pliku `test.txt` bezpośrednio w notatniku.
# 7. Użyj `%who` aby zobaczyć zdefiniowane zmienne.
#
# --------
#
# # Ćwiczenie 8: Debugowanie i profilowanie
#
# 1. Napisz prostą funkcję, która może wygenerować błąd (np. dzielenie przez zero).
# 2. Użyj `%debug` aby przejść do trybu debugowania po wystąpieniu błędu.
# 5. Użyj `%prun` do profilowania kodu.
#
# --------
#
# # Zadanie domowe 1: Instalacja Jupyter na komputerze domowym
#
# 1. **Instalacja środowiska**
#    - Zainstaluj Pythona w wersji 3.8+ ze strony [python.org](https://www.python.org/downloads/)
#    - Upewnij się, że Python został dodany do zmiennych środowiskowych
#    - Otwórz wiersz poleceń (cmd/PowerShell) i wykonaj:
#      ```bash
#      pip install --upgrade pip
#      pip install notebook jupyter
#      ```
#
# 2. **Weryfikacja instalacji**
#    - Uruchom Jupyter Notebook komendą:
#      ```bash
#      jupyter notebook
#      ```
#    - Sprawdź, czy w przeglądarce otwiera się interfejs Jupyter
#    - Stwórz nowy notatnik i wykonaj prostą operację (np. `print("Witaj w Jupyterze!")`)
#
# --------
#
# # Zadanie domowe 2: Analiza danych w Jupyterze
#
# 1. **Przygotowanie środowiska**
#    - Zainstaluj niezbędne biblioteki:
#      ```bash
#      pip install pandas matplotlib seaborn
#      ```
#
# 2. **Eksploracja danych**
#    - Pobierz jeden z poniższych zestawów danych:
#      - [Titanic Dataset](https://www.kaggle.com/c/titanic/data) (prosty, dobry na początek)
#      - [Iris Dataset](https://archive.ics.uci.edu/ml/datasets/iris) (klasyczny zbiór do nauki)
#      - [Netflix Movies and TV Shows](https://www.kaggle.com/datasets/shivamb/netflix-shows) (ciekawy zbiór o filmach i serialach)
#
# 3. **Notatnik analityczny**
#    Przygotuj notatnik Jupyter zawierający:
#
#    **Komórki Markdown:**
#    - Tytuł i krótki opis analizowanego zbioru danych
#    - Źródło danych i ich licencja
#    - Cel analizy
#
#    **Komórki kodu:**
#    ```python
#    # Wczytanie danych
#    import pandas as pd
#    df = pd.read_csv('sciezka_do_pliku.csv')
#    ```
#    ```python
#    # Podstawowe informacje o danych
#    df.info()
#    df.describe()
#    ```
#    ```python
#    # Prosta wizualizacja
#    import matplotlib.pyplot as plt
#    df['nazwa_kolumny'].value_counts().plot(kind='bar')
#    plt.title('Rozkład danych')
#    plt.show()
#    ```
#
#    **Podsumowanie:**
#    - 3 najciekawsze obserwacje z analizy
#    - Ewentualne problemy napotkane podczas analizy
#    - Propozycje dalszych badań
#
# 4. **Wskazówki**
#    - Używaj nagłówków (##, ###) do porządkowania notatnika
#    - Komentuj swój kod
#    - Zapisz notatnik w formacie .ipynb i wyeksportuj do HTML/PDF
